# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
import numpy as np

# %%
data = pd.read_csv("chiago-stats-preprocessed.csv")

# %%
data
# Out:
#       block-pct-last-1  defensive-efficiency-last-1  \
# 0                  7.1                        0.945
# 1                  7.1                        0.945
# 2                  6.4                        1.071
# 3                  6.4                        1.071
# 4                  3.1                        1.016
# ...                ...                          ...
# 3029               8.9                        1.060
# 3030               8.9                        1.060
# 3031               8.9                        1.060
# 3032               8.9                        1.060
# 3033               8.9                        1.060
#
#       offensive-efficiency-last-1  steal-pct-last-1  \
# 0                           0.841              12.0
# 1                           0.841              12.0
# 2                           1.094               7.3
# 3                           1.094               7.3
# 4                           1.096               7.6
# ...

# %%
X=data.iloc[:,:-1].values
y=data['changes_of_win_rating'].values

# %%
#separates data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Decision Tree Algorithm
decision_model = DecisionTreeClassifier()

#KNN Algorithm
knn_model = KNeighborsClassifier()

#Logistic Regression Algorithm
logistic_model = LogisticRegression()

#Naive Bayes Algorithm
naive_model = GaussianNB()

#Random Forest Algorithm
random_model = RandomForestClassifier()

#AdaBoost Algorithm 
ada_model = AdaBoostClassifier()

#SV Classifier Algorithm
sv_model = SVC()

#Multi-Layer Perceptron Algorithm
multi_model = MLPClassifier()

# %%
def regressionAlgorithm(reg_model, X_train, X_test, y_train, y_test, reg_name):
    model = reg_model
    model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    #Residual Plot
    plt.scatter(np.arange(len(y_test)), y_test, color = "red", label = "Exact Values")
    plt.scatter(np.arange(len(y_test_pred)), y_test_pred, color = "blue", label = "Predicted Value")
    #plt.hlines(y=0, xmin=0, xmax=80, color= 'blue')
    plt.title(reg_name)
    plt.ylabel('Values')
    plt.xlabel('Indices')
    plt.legend()
    plt.show()
    
    print(reg_name, "Scores")
    print("Train MSE =", mean_squared_error(y_train, y_train_pred))
    print("Train R2 =", r2_score(y_train, y_train_pred))
    print("Test MSE =", mean_squared_error(y_test, y_test_pred))
    print("Test R2 =", r2_score(y_test, y_test_pred))
    print("Model Accuracy = ", accuracy_score(y_test, y_test_pred))
    
    acc_values[reg_name] = accuracy_score(y_test, y_test_pred)
    train_mse_values[reg_name] = mean_squared_error(y_train, y_train_pred)
    test_mse_values[reg_name] = mean_squared_error(y_test, y_test_pred)
    train_r2_values[reg_name] = r2_score(y_train, y_train_pred)
    test_r2_values[reg_name] = r2_score(y_test, y_test_pred)
    
    print("------------------------------------------------------------------")

# %%
def dic2bar(title, dic):
    keys = dic.keys()
    values = dic.values()
    plt.xticks(rotation=90)
    plt.title(title)
    plt.bar(keys, values)

# %%
acc_values = {}
train_mse_values = {}
test_mse_values = {}
train_r2_values = {}
test_r2_values = {}

# %%
regressionAlgorithm(decision_model, X_train, X_test, y_train, y_test, 'Decision Tree Algorithm')
# Out:
# Decision Tree Algorithm Scores
# Train MSE = 0.0
# Train R2 = 1.0
# Test MSE = 0.019769357495881382
# Test R2 = 0.9792749062476882
# Model Accuracy =  0.9950576606260296
# ------------------------------------------------------------------

# %%
regressionAlgorithm(knn_model, X_train, X_test, y_train, y_test, 'KNN Algorithm')
# Out:
# KNN Algorithm Scores
# Train MSE = 0.2196126905644829
# Train R2 = 0.7684888927227764
# Test MSE = 0.3311367380560132
# Test R2 = 0.6528546796487773
# Model Accuracy =  0.9159802306425041
# ------------------------------------------------------------------

# %%
regressionAlgorithm(logistic_model, X_train, X_test, y_train, y_test, 'Logistic Regression Algorithm')
# Out:
# C:\Users\Soner\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Algorithm Scores
# Train MSE = 0.37783271528636175
# Train R2 = 0.601696650331681
# Test MSE = 0.31795716639209226
# Test R2 = 0.6666714088169852
# Model Accuracy =  0.9192751235584844
# ------------------------------------------------------------------

# %%
regressionAlgorithm(naive_model, X_train, X_test, y_train, y_test, 'Naive Bayes Algorithm')
# Out:
# Naive Bayes Algorithm Scores
# Train MSE = 0.3296250515039143
# Train R2 = 0.6525161616852179
# Test MSE = 0.24546952224052718
# Test R2 = 0.7426634192421284
# Model Accuracy =  0.9373970345963756
# ------------------------------------------------------------------

# %%
regressionAlgorithm(random_model, X_train, X_test, y_train, y_test, 'Random Forest Algorithm')
# Out:
# Random Forest Algorithm Scores
# Train MSE = 0.0
# Train R2 = 1.0
# Test MSE = 0.006589785831960461
# Test R2 = 0.9930916354158961
# Model Accuracy =  0.9983525535420099
# ------------------------------------------------------------------

# %%
regressionAlgorithm(ada_model, X_train, X_test, y_train, y_test, 'AdaBoost Algorithm ')
# Out:
# AdaBoost Algorithm  Scores
# Train MSE = 0.8751545117428925
# Train R2 = 0.07743040927425349
# Test MSE = 0.8434925864909391
# Test R2 = 0.11572933323469647
# Model Accuracy =  0.7891268533772653
# ------------------------------------------------------------------

# %%
regressionAlgorithm(sv_model, X_train, X_test, y_train, y_test, 'SV Classifier Algorithm')
# Out:
# SV Classifier Algorithm Scores
# Train MSE = 1.5480016481252574
# Train R2 = -0.6318709756857956
# Test MSE = 1.5766062602965403
# Test R2 = -0.6528262267468663
# Model Accuracy =  0.6046128500823723
# ------------------------------------------------------------------

# %%
regressionAlgorithm(multi_model, X_train, X_test, y_train, y_test, 'Multi-Layer Perceptron Algorithm')
# Out:
# Multi-Layer Perceptron Algorithm Scores
# Train MSE = 1.1326740832303255
# Train R2 = -0.19404133940917
# Test MSE = 1.1021416803953872
# Test R2 = -0.15542397669138297
# Model Accuracy =  0.7232289950576606
# ------------------------------------------------------------------

# %%
dic2bar("Accuracy Scores", acc_values)

# %%
dic2bar("Train MSE Values", train_mse_values)

# %%
dic2bar("Test MSE Values", test_mse_values)

# %%
dic2bar("Train R2 Values", train_r2_values)

# %%
dic2bar("Test R2 Values", test_r2_values)

# %% [markdown]
# # predictions

# %%
def makePrediction(lastGameCount=data.shape[0], year=2021, month=6, day=2, model=random_model):
    featureCount = (len(data.iloc[0])-4)

    prediction = [0]*featureCount # 4: year, month, day

    for i in range(-lastGameCount, -1):
        currentData = data.iloc[i]
        currentData = currentData.drop(["year", "month", "day", "changes_of_win_rating"])
        for index in range(len(currentData)):
            prediction[index] += currentData[index]
            
    prediction = [feature/lastGameCount for feature in prediction]
    prediction.append(year)
    prediction.append(month)
    prediction.append(day)
    
    pred = model.predict(pd.Series(prediction).values.reshape(1, -1))[0]
    return str("date: " + str(year) + "-" + str(month) + "-" + str(day) + ", last " + str(lastGameCount) + " game"), pred

# %%
preds = {}

# %%
label, pred = makePrediction(lastGameCount=200)
preds[label] = pred

# %%
label, pred = makePrediction(lastGameCount=100)
preds[label] = pred

# %%
label, pred = makePrediction(lastGameCount=10)
preds[label] = pred

# %%
label, pred = makePrediction(lastGameCount = 7, year=2023, month=5, day=1)
preds[label] = pred

# %%
label, pred = makePrediction()
preds[label] = pred

# %%
label, pred = makePrediction(lastGameCount = 3, year=2022, month=12, day=31)
preds[label] = pred

# %%
label, pred = makePrediction(lastGameCount = 16, year=2028, month=2, day=5)
preds[label] = pred

# %%
label, pred = makePrediction(lastGameCount = 7, year=2022, month=10, day=1)
preds[label] = pred

# %%
label, pred = makePrediction(lastGameCount = 1000, year=2021, month=8, day=12)
preds[label] = pred

# %%
label, pred = makePrediction(lastGameCount = 1)
preds[label] = pred

# %%
dic2bar("predictions", preds)

# %%
plt.title("Histogram of Predictions")
plt.hist(preds.values())
# Out:
# (array([4., 0., 0., 0., 0., 0., 0., 0., 0., 6.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <BarContainer object of 10 artists>)
